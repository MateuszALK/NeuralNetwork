# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import matplotlib.image as mpimg
import cv2

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout
import os

# %%
images=[]
z=[]
location=os.getcwd()
folders=os.listdir(location+"\\data")
for item in folders:
    for picture in os.listdir(str(location)+"\\data"+"\\"+str(item)):
        img=cv2.imread(location+"\\data"+"\\"+str(item)+"\\"+str(picture))
        res = cv2.resize(img, dsize=(50, 50), interpolation=cv2.INTER_CUBIC)
        x.append(res)
        z.append(item)
dataset=np.concatenate(images)

# %%
# Out:
# ['airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
#  'airplane',
# ...

# %%
# Out:
# 1972

# %%
# Out:
#   File "<ipython-input-21-faf1f457479f>", line 1
#     z[z.key=1972]
#            ^
# SyntaxError: invalid syntax
